# %% [markdown]
# # NAME: KIPLANGAT ENOCK RONO
# ## FILE: Assignment.ipynb

# %% [markdown]
# ### QUESTION ONE: Strings and Collections
# **a)** Count words
# **b)** Reverse word list
# **c)** Replace 'important' with 'essential'

# %%
sentence = "Data Structures and Algorithms are important in problem solving"

# a) Count the number of words
word_count = len(sentence.split())
print(f"a) Number of words = {word_count}")

# b) Convert to list and display in reverse order
words_list = sentence.split()
reversed_words = words_list[::-1]
print(f"b) Reversed words = {reversed_words}")

# c) Replace 'important' with 'essential'
new_sentence = sentence.replace("important", "essential")
print(f"c) New sentence = {new_sentence}")

# %% [markdown]
# ### QUESTION TWO: Algorithm Analysis
# **a) Definitions:**
# *   **Big-O:** Upper bound (Worst-case).
# *   **Big-Θ:** Tight bound (Average-case).
# *   **Big-Ω:** Lower bound (Best-case).
#
# **b) Complexity:**
# The nested loop runs $n \times n$ times, resulting in **O(n²)** complexity. This is inefficient for large $n$ (e.g., $100,000$ results in $10^{10}$ operations).

# %% [markdown]
# ### QUESTION THREE: Searching and Sorting

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target: return i
    return -1

def binary_search(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target: return mid
        elif arr[mid] < target: low = mid + 1
        else: high = mid - 1
    return -1

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

arr = [21, 10, 45, 32, 67, 5, 18]
print(f"Linear Search (32): Index {linear_search(arr, 32)}")
sorted_arr = sorted(arr)
print(f"Binary Search (45): Index {binary_search(sorted_arr, 45)}")
print(f"Bubble Sort: {bubble_sort(arr[:])}")

# %% [markdown]
# ### QUESTION FOUR: Linked Lists

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None    

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next: current = current.next
        current.next = new_node

    def display(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

my_list = LinkedList()
my_list.insert_at_beginning(10)
my_list.insert_at_end(20)
my_list.insert_at_beginning(5)
my_list.display()

# %% [markdown]
# ### QUESTION FIVE: Application - Finance Office Queue
# **Data Structure:** Queue (FIFO). This ensures students are served in the order they arrive.

# %%
from collections import deque

class FinanceSystem:
    def __init__(self):
        self.queue = deque()

    def add_student(self, name):
        self.queue.append(name)
        print(f"{name} joined the queue.")

    def serve_student(self):
        if self.queue:
            print(f"Serving: {self.queue.popleft()}")
        else:
            print("Queue empty.")

    def display_queue(self):
        print(f"Current Queue: {list(self.queue)}")

finance = FinanceSystem()
finance.add_student("Enock")
finance.add_student("Kiplangat")
finance.display_queue()
finance.serve_student()
finance.display_queue()
